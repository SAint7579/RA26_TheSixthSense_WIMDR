# %%
# !nvidia-smi
# Out:
# Fri Jul 31 21:23:24 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install -U tensorflow -q
# Out:
#      |████████████████████████████████| 320.4MB 54kB/s
#      |████████████████████████████████| 6.8MB 26.5MB/s
#      |████████████████████████████████| 460kB 53.9MB/s

# %%
# !pip uninstall keras-applications --yes
# Out:
# Uninstalling Keras-Applications-1.0.8:
#   Successfully uninstalled Keras-Applications-1.0.8

# %%
# !pip install git+https://github.com/keras-team/keras-applications.git@master
# Out:
# Collecting git+https://github.com/keras-team/keras-applications.git@master
#   Cloning https://github.com/keras-team/keras-applications.git (to revision master) to /tmp/pip-req-build-bskfq87i
#   Running command git clone -q https://github.com/keras-team/keras-applications.git /tmp/pip-req-build-bskfq87i
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras-Applications==1.0.8) (1.18.5)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras-Applications==1.0.8) (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras-Applications==1.0.8) (1.15.0)
# Building wheels for collected packages: Keras-Applications
#   Building wheel for Keras-Applications (setup.py) ... done
#   Created wheel for Keras-Applications: filename=Keras_Applications-1.0.8-cp36-none-any.whl size=62000 sha256=67be0c743b759b76a53cc00b6c1a125659b0569cf012a29d8f158b79f2a3df7c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9b99si9o/wheels/f8/3c/48/007f19c86cc5d5f276a748f003a63bc19558539eab93afb545
# Successfully built Keras-Applications
# Installing collected packages: Keras-Applications
# Successfully installed Keras-Applications-1.0.8

# %%
from keras.applications import keras_applications
from keras_applications import mobilenet_v3
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
import numpy as np

# %%
import cv2
import matplotlib.pyplot as plt

# %%
base_model = mobilenet_v3.MobileNetV3Small(input_shape=(None, None, 3),
                              alpha=0.75,
                              minimalistic=False,
                              include_top=False,
                              weights="imagenet",
                              backend=tf.keras.backend,
                              layers=tf.keras.layers,
                              models=tf.keras.models,
                              utils=tf.keras.utils
                              )
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/mobilenet_v3.py:348: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '

# %%
base_model.trainable = False

# %%
out = base_model.predict(np.random.randn(1,320,320,3))
out.shape
# Out:
# (1, 10, 10, 432)

# %%
num_classes = 1

# %%
sf = tf.keras.layers.Conv2D(128, kernel_size=1, strides=1)(base_model.output) # try batch norm
sf = tf.keras.layers.Activation(mobilenet_v3.hard_swish)(sf)
sf = tf.keras.layers.Conv2DTranspose(64, kernel_size=3, strides=2, padding="same")(sf)
sf = tf.keras.layers.Activation(mobilenet_v3.hard_swish)(sf)
sf = tf.keras.layers.Conv2D(num_classes, kernel_size=1, strides=1)(sf)
sf = tf.keras.layers.Activation('sigmoid')(sf)
sf.shape
# Out:
# TensorShape([None, None, None, 1])

# %%
model = tf.keras.models.Model(base_model.input, outputs=sf)

# %%
model.summary()
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# Conv_pad (ZeroPadding2D)        (None, None, None, 3 0           input_3[0][0]
# __________________________________________________________________________________________________
# Conv (Conv2D)                   (None, None, None, 1 432         Conv_pad[0][0]
# __________________________________________________________________________________________________
# Conv/BatchNorm (BatchNormalizat (None, None, None, 1 64          Conv[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, None, None, 1 0           Conv/BatchNorm[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise/pad (Ze (None, None, None, 1 0           activation_70[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise (Depthw (None, None, None, 1 144         expanded_conv/depthwise/pad[0][0]
# __________________________________________________________________________________________________
# expanded_conv/depthwise/BatchNo (None, None, None, 1 64          expanded_conv/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, None, None, 1 0           expanded_conv/depthwise/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Av (None, 16)           0           activation_71[0][0]
# __________________________________________________________________________________________________
# reshape_18 (Reshape)            (None, 1, 1, 16)     0           expanded_conv/squeeze_excite/AvgP
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Co (None, 1, 1, 8)      136         reshape_18[0][0]
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Re (None, 1, 1, 8)      0           expanded_conv/squeeze_excite/Conv
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Co (None, 1, 1, 16)     144         expanded_conv/squeeze_excite/Relu
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 1, 1, 16)     0           expanded_conv/squeeze_excite/Conv
# __________________________________________________________________________________________________
# expanded_conv/squeeze_excite/Mu (None, None, None, 1 0           activation_71[0][0]
#                                                                  activation_72[0][0]
# __________________________________________________________________________________________________
# expanded_conv/project (Conv2D)  (None, None, None, 1 256         expanded_conv/squeeze_excite/Mul[
# __________________________________________________________________________________________________
# expanded_conv/project/BatchNorm (None, None, None, 1 64          expanded_conv/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/expand (Conv2D) (None, None, None, 7 1152        expanded_conv/project/BatchNorm[0
# __________________________________________________________________________________________________
# expanded_conv_1/expand/BatchNor (None, None, None, 7 288         expanded_conv_1/expand[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, None, None, 7 0           expanded_conv_1/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise/pad ( (None, None, None, 7 0           activation_73[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise (Dept (None, None, None, 7 648         expanded_conv_1/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_1/depthwise/Batch (None, None, None, 7 288         expanded_conv_1/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, None, None, 7 0           expanded_conv_1/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_1/project (Conv2D (None, None, None, 2 1728        activation_74[0][0]
# __________________________________________________________________________________________________
# expanded_conv_1/project/BatchNo (None, None, None, 2 96          expanded_conv_1/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/expand (Conv2D) (None, None, None, 8 2112        expanded_conv_1/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_2/expand/BatchNor (None, None, None, 8 352         expanded_conv_2/expand[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, None, None, 8 0           expanded_conv_2/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_2/depthwise (Dept (None, None, None, 8 792         activation_75[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/depthwise/Batch (None, None, None, 8 352         expanded_conv_2/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, None, None, 8 0           expanded_conv_2/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_2/project (Conv2D (None, None, None, 2 2112        activation_76[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/project/BatchNo (None, None, None, 2 96          expanded_conv_2/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_2/Add (Add)       (None, None, None, 2 0           expanded_conv_1/project/BatchNorm
#                                                                  expanded_conv_2/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_3/expand (Conv2D) (None, None, None, 9 2304        expanded_conv_2/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/expand/BatchNor (None, None, None, 9 384         expanded_conv_3/expand[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, None, None, 9 0           expanded_conv_3/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise/pad ( (None, None, None, 9 0           activation_77[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise (Dept (None, None, None, 9 2400        expanded_conv_3/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_3/depthwise/Batch (None, None, None, 9 384         expanded_conv_3/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, None, None, 9 0           expanded_conv_3/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 96)           0           activation_78[0][0]
# __________________________________________________________________________________________________
# reshape_19 (Reshape)            (None, 1, 1, 96)     0           expanded_conv_3/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 24)     2328        reshape_19[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 24)     0           expanded_conv_3/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, 1, 1, 96)     2400        expanded_conv_3/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 1, 1, 96)     0           expanded_conv_3/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_3/squeeze_excite/ (None, None, None, 9 0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# expanded_conv_3/project (Conv2D (None, None, None, 3 3072        expanded_conv_3/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_3/project/BatchNo (None, None, None, 3 128         expanded_conv_3/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/expand (Conv2D) (None, None, None, 1 6144        expanded_conv_3/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_4/expand/BatchNor (None, None, None, 1 768         expanded_conv_4/expand[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, None, None, 1 0           expanded_conv_4/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_4/depthwise (Dept (None, None, None, 1 4800        activation_80[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/depthwise/Batch (None, None, None, 1 768         expanded_conv_4/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, None, None, 1 0           expanded_conv_4/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 192)          0           activation_81[0][0]
# __________________________________________________________________________________________________
# reshape_20 (Reshape)            (None, 1, 1, 192)    0           expanded_conv_4/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 48)     9264        reshape_20[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 48)     0           expanded_conv_4/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, 1, 1, 192)    9408        expanded_conv_4/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 1, 1, 192)    0           expanded_conv_4/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_4/squeeze_excite/ (None, None, None, 1 0           activation_81[0][0]
#                                                                  activation_82[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/project (Conv2D (None, None, None, 3 6144        expanded_conv_4/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_4/project/BatchNo (None, None, None, 3 128         expanded_conv_4/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_4/Add (Add)       (None, None, None, 3 0           expanded_conv_3/project/BatchNorm
#                                                                  expanded_conv_4/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_5/expand (Conv2D) (None, None, None, 1 6144        expanded_conv_4/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/expand/BatchNor (None, None, None, 1 768         expanded_conv_5/expand[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, None, None, 1 0           expanded_conv_5/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_5/depthwise (Dept (None, None, None, 1 4800        activation_83[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/depthwise/Batch (None, None, None, 1 768         expanded_conv_5/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, None, None, 1 0           expanded_conv_5/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 192)          0           activation_84[0][0]
# __________________________________________________________________________________________________
# reshape_21 (Reshape)            (None, 1, 1, 192)    0           expanded_conv_5/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 48)     9264        reshape_21[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 48)     0           expanded_conv_5/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, 1, 1, 192)    9408        expanded_conv_5/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 1, 1, 192)    0           expanded_conv_5/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_5/squeeze_excite/ (None, None, None, 1 0           activation_84[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/project (Conv2D (None, None, None, 3 6144        expanded_conv_5/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_5/project/BatchNo (None, None, None, 3 128         expanded_conv_5/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_5/Add (Add)       (None, None, None, 3 0           expanded_conv_4/Add[0][0]
#                                                                  expanded_conv_5/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_6/expand (Conv2D) (None, None, None, 9 3072        expanded_conv_5/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/expand/BatchNor (None, None, None, 9 384         expanded_conv_6/expand[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, None, None, 9 0           expanded_conv_6/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise (Dept (None, None, None, 9 2400        activation_86[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/depthwise/Batch (None, None, None, 9 384         expanded_conv_6/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, None, None, 9 0           expanded_conv_6/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 96)           0           activation_87[0][0]
# __________________________________________________________________________________________________
# reshape_22 (Reshape)            (None, 1, 1, 96)     0           expanded_conv_6/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 24)     2328        reshape_22[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 24)     0           expanded_conv_6/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, 1, 1, 96)     2400        expanded_conv_6/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 1, 1, 96)     0           expanded_conv_6/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_6/squeeze_excite/ (None, None, None, 9 0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# expanded_conv_6/project (Conv2D (None, None, None, 4 3840        expanded_conv_6/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_6/project/BatchNo (None, None, None, 4 160         expanded_conv_6/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/expand (Conv2D) (None, None, None, 1 4800        expanded_conv_6/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_7/expand/BatchNor (None, None, None, 1 480         expanded_conv_7/expand[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, None, None, 1 0           expanded_conv_7/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_7/depthwise (Dept (None, None, None, 1 3000        activation_89[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/depthwise/Batch (None, None, None, 1 480         expanded_conv_7/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, None, None, 1 0           expanded_conv_7/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 120)          0           activation_90[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 1, 1, 120)    0           expanded_conv_7/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 32)     3872        reshape_23[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 32)     0           expanded_conv_7/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, 1, 1, 120)    3960        expanded_conv_7/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 1, 1, 120)    0           expanded_conv_7/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_7/squeeze_excite/ (None, None, None, 1 0           activation_90[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/project (Conv2D (None, None, None, 4 4800        expanded_conv_7/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_7/project/BatchNo (None, None, None, 4 160         expanded_conv_7/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_7/Add (Add)       (None, None, None, 4 0           expanded_conv_6/project/BatchNorm
#                                                                  expanded_conv_7/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_8/expand (Conv2D) (None, None, None, 2 9600        expanded_conv_7/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/expand/BatchNor (None, None, None, 2 960         expanded_conv_8/expand[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, None, None, 2 0           expanded_conv_8/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise/pad ( (None, None, None, 2 0           activation_92[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise (Dept (None, None, None, 2 6000        expanded_conv_8/depthwise/pad[0][
# __________________________________________________________________________________________________
# expanded_conv_8/depthwise/Batch (None, None, None, 2 960         expanded_conv_8/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, None, None, 2 0           expanded_conv_8/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 240)          0           activation_93[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 1, 1, 240)    0           expanded_conv_8/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 64)     15424       reshape_24[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 64)     0           expanded_conv_8/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, 1, 1, 240)    15600       expanded_conv_8/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 1, 1, 240)    0           expanded_conv_8/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_8/squeeze_excite/ (None, None, None, 2 0           activation_93[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# expanded_conv_8/project (Conv2D (None, None, None, 7 17280       expanded_conv_8/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_8/project/BatchNo (None, None, None, 7 288         expanded_conv_8/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/expand (Conv2D) (None, None, None, 4 31104       expanded_conv_8/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_9/expand/BatchNor (None, None, None, 4 1728        expanded_conv_9/expand[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, None, None, 4 0           expanded_conv_9/expand/BatchNorm[
# __________________________________________________________________________________________________
# expanded_conv_9/depthwise (Dept (None, None, None, 4 10800       activation_95[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/depthwise/Batch (None, None, None, 4 1728        expanded_conv_9/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, None, None, 4 0           expanded_conv_9/depthwise/BatchNo
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 432)          0           activation_96[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 1, 1, 432)    0           expanded_conv_9/squeeze_excite/Av
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 112)    48496       reshape_25[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 112)    0           expanded_conv_9/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, 1, 1, 432)    48816       expanded_conv_9/squeeze_excite/Re
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 1, 1, 432)    0           expanded_conv_9/squeeze_excite/Co
# __________________________________________________________________________________________________
# expanded_conv_9/squeeze_excite/ (None, None, None, 4 0           activation_96[0][0]
#                                                                  activation_97[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/project (Conv2D (None, None, None, 7 31104       expanded_conv_9/squeeze_excite/Mu
# __________________________________________________________________________________________________
# expanded_conv_9/project/BatchNo (None, None, None, 7 288         expanded_conv_9/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_9/Add (Add)       (None, None, None, 7 0           expanded_conv_8/project/BatchNorm
#                                                                  expanded_conv_9/project/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_10/expand (Conv2D (None, None, None, 4 31104       expanded_conv_9/Add[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/expand/BatchNo (None, None, None, 4 1728        expanded_conv_10/expand[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, None, None, 4 0           expanded_conv_10/expand/BatchNorm
# __________________________________________________________________________________________________
# expanded_conv_10/depthwise (Dep (None, None, None, 4 10800       activation_98[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/depthwise/Batc (None, None, None, 4 1728        expanded_conv_10/depthwise[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, None, None, 4 0           expanded_conv_10/depthwise/BatchN
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 432)          0           activation_99[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 1, 1, 432)    0           expanded_conv_10/squeeze_excite/A
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 112)    48496       reshape_26[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 112)    0           expanded_conv_10/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, 1, 1, 432)    48816       expanded_conv_10/squeeze_excite/R
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 1, 1, 432)    0           expanded_conv_10/squeeze_excite/C
# __________________________________________________________________________________________________
# expanded_conv_10/squeeze_excite (None, None, None, 4 0           activation_99[0][0]
#                                                                  activation_100[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/project (Conv2 (None, None, None, 7 31104       expanded_conv_10/squeeze_excite/M
# __________________________________________________________________________________________________
# expanded_conv_10/project/BatchN (None, None, None, 7 288         expanded_conv_10/project[0][0]
# __________________________________________________________________________________________________
# expanded_conv_10/Add (Add)      (None, None, None, 7 0           expanded_conv_9/Add[0][0]
#                                                                  expanded_conv_10/project/BatchNor
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, None, None, 4 31104       expanded_conv_10/Add[0][0]
# __________________________________________________________________________________________________
# Conv_1/BatchNorm (BatchNormaliz (None, None, None, 4 1728        Conv_1[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, None, None, 4 0           Conv_1/BatchNorm[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 55424       activation_101[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, None, None, 1 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, None, None, 6 73792       activation_102[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, None, None, 6 0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 65          activation_103[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, None, None, 1 0           conv2d_5[0][0]
# ==================================================================================================
# Total params: 712,441
# Trainable params: 129,281
# Non-trainable params: 583,160
# __________________________________________________________________________________________________

# %%
base_learning_rate = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy']
              )

# %%
out = model.predict(np.random.randn(1,320,320,3))
out.shape
# Out:
# WARNING:tensorflow:5 out of the last 157 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fdb44a47620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# (1, 20, 20, 1)

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
BATCH_SIZE = 64
IMG_HEIGHT = 320
IMG_WIDTH = 320
OUT_HEIGHT = 20
OUT_WIDTH = 20

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !cp /content/drive/My\ Drive/garbage_dataset.zip /content/

# %%
# !unzip -q garbage_dataset.zip

# %%
list_ds = tf.data.Dataset.list_files("garbage_dataset/train/*")
valid_ds = tf.data.Dataset.list_files("garbage_dataset/test/*")

# %%
LEN_DS = len(list(list_ds))

# %%
for f in list_ds.take(1):
    print(f)
# Out:
# tf.Tensor(b'garbage_dataset/train/50437222-9439-11e5-bc72-40f2e96c8ad8.jpg', shape=(), dtype=string)

# %%
import pickle
with open('labels.pickle', 'rb') as f:
    lbls = pickle.load(f)

# %%
def get_label(file_path):
    parts = tf.strings.split(file_path, '/')
    label = lbls[parts[-1].numpy().decode()]
    label = tf.convert_to_tensor(label, tf.float32)
    return label

# %%
get_label_wrapper = lambda x: tf.py_function(get_label, [x], tf.float32)

# %%
def decode_img(img):
    img = tf.io.decode_image(img, channels=3, expand_animations = False)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.image.resize(img, [IMG_WIDTH, IMG_HEIGHT])
    return img#*2 - 1

# %%
def process_path(file_path):
    label = get_label_wrapper(file_path)
    label.set_shape([OUT_HEIGHT, OUT_WIDTH, num_classes])
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
labeled_ds = list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
labeled_test_ds = valid_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in labeled_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy().shape)
# Out:
# Image shape:  (320, 320, 3)
# Label:  (20, 20, 1)

# %%
image.numpy().min()
# Out:
# -1.0

# %%
def prepare_for_training(ds, cache=True):
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    ds = ds.shuffle(buffer_size=100)
    ds = ds.repeat() #repeat forever
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

# %%
train_ds = prepare_for_training(labeled_ds)
test_ds = prepare_for_training(labeled_test_ds)

# %%
def lr_scheduler(epoch, lr):
    if not epoch % 4 and epoch:
        return lr/2
    return lr
lrsc = tf.keras.callbacks.LearningRateScheduler(lr_scheduler, verbose=1)

# %%
history = model.fit(train_ds,
                    epochs=15,
                    steps_per_epoch=40,
                    validation_data=test_ds,
                    validation_steps=6,
                    callbacks=[lrsc])
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 1/15
# 40/40 [==============================] - 42s 1s/step - loss: 0.3097 - accuracy: 0.8897 - val_loss: 0.1950 - val_accuracy: 0.9273
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 2/15
# 40/40 [==============================] - 3s 82ms/step - loss: 0.1922 - accuracy: 0.9251 - val_loss: 0.1893 - val_accuracy: 0.9267
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 3/15
# 40/40 [==============================] - 3s 82ms/step - loss: 0.1733 - accuracy: 0.9306 - val_loss: 0.1632 - val_accuracy: 0.9360
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# Epoch 4/15
# 40/40 [==============================] - 3s 82ms/step - loss: 0.1575 - accuracy: 0.9370 - val_loss: 0.1680 - val_accuracy: 0.9328
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 5/15
# 40/40 [==============================] - 3s 82ms/step - loss: 0.1443 - accuracy: 0.9420 - val_loss: 0.1687 - val_accuracy: 0.9333
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 6/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.1356 - accuracy: 0.9457 - val_loss: 0.1639 - val_accuracy: 0.9357
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 7/15
# 40/40 [==============================] - 3s 82ms/step - loss: 0.1316 - accuracy: 0.9470 - val_loss: 0.1639 - val_accuracy: 0.9357
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0005000000237487257.
# Epoch 8/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.1268 - accuracy: 0.9493 - val_loss: 0.1689 - val_accuracy: 0.9339
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 9/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.1213 - accuracy: 0.9514 - val_loss: 0.1658 - val_accuracy: 0.9354
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 10/15
# 40/40 [==============================] - 3s 84ms/step - loss: 0.1188 - accuracy: 0.9525 - val_loss: 0.1684 - val_accuracy: 0.9342
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 11/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.1163 - accuracy: 0.9536 - val_loss: 0.1794 - val_accuracy: 0.9306
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0002500000118743628.
# Epoch 12/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.1131 - accuracy: 0.9550 - val_loss: 0.1749 - val_accuracy: 0.9330
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 13/15
# 40/40 [==============================] - 3s 84ms/step - loss: 0.1134 - accuracy: 0.9545 - val_loss: 0.1751 - val_accuracy: 0.9330
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 14/15
# 40/40 [==============================] - 3s 84ms/step - loss: 0.1124 - accuracy: 0.9545 - val_loss: 0.1748 - val_accuracy: 0.9337
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0001250000059371814.
# Epoch 15/15
# 40/40 [==============================] - 3s 83ms/step - loss: 0.1103 - accuracy: 0.9555 - val_loss: 0.1805 - val_accuracy: 0.9312

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.ylabel('Accuracy')
# plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
# plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
for lyr in model.layers[-57:]:
    lyr.trainable=True

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(lr=base_learning_rate/10),
              loss=tf.keras.losses.BinaryCrossentropy(),
              metrics=['accuracy'])

# %%
history_fine = model.fit(train_ds,
                         epochs=20,
                         steps_per_epoch=40,
                        #  initial_epoch = history.epoch[-1]+1,
                         validation_data=test_ds,
                         validation_steps=6,
                         callbacks=[lrsc])
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 2.4414061883248905e-08.
# Epoch 1/20
#  2/40 [>.............................] - ETA: 4s - loss: 0.0225 - accuracy: 0.9917WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0912s vs `on_train_batch_end` time: 0.1413s). Check your callbacks.
# 40/40 [==============================] - 9s 236ms/step - loss: 0.0290 - accuracy: 0.9887 - val_loss: 0.1907 - val_accuracy: 0.9484
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 2.4414061883248905e-08.
# Epoch 2/20
# 40/40 [==============================] - 9s 237ms/step - loss: 0.0287 - accuracy: 0.9890 - val_loss: 0.1999 - val_accuracy: 0.9462
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 2.4414061883248905e-08.
# Epoch 3/20
# 40/40 [==============================] - 9s 237ms/step - loss: 0.0290 - accuracy: 0.9887 - val_loss: 0.2059 - val_accuracy: 0.9455
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 2.4414061883248905e-08.
# Epoch 4/20
# 40/40 [==============================] - 10s 238ms/step - loss: 0.0284 - accuracy: 0.9890 - val_loss: 0.1971 - val_accuracy: 0.9477
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 1.2207030941624453e-08.
# Epoch 5/20
# 40/40 [==============================] - 10s 239ms/step - loss: 0.0294 - accuracy: 0.9886 - val_loss: 0.2046 - val_accuracy: 0.9458
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 1.2207030941624453e-08.
# Epoch 6/20
# 40/40 [==============================] - 10s 241ms/step - loss: 0.0296 - accuracy: 0.9886 - val_loss: 0.1940 - val_accuracy: 0.9487
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 1.2207030941624453e-08.
# Epoch 7/20
# 40/40 [==============================] - 10s 242ms/step - loss: 0.0287 - accuracy: 0.9888 - val_loss: 0.1946 - val_accuracy: 0.9486
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 1.2207030941624453e-08.
# Epoch 8/20
# 40/40 [==============================] - 10s 241ms/step - loss: 0.0289 - accuracy: 0.9888 - val_loss: 0.1944 - val_accuracy: 0.9481
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 6.103515470812226e-09.
# Epoch 9/20
# 40/40 [==============================] - 10s 245ms/step - loss: 0.0290 - accuracy: 0.9888 - val_loss: 0.1948 - val_accuracy: 0.9484
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 6.103515470812226e-09.
# Epoch 10/20
# 40/40 [==============================] - 10s 244ms/step - loss: 0.0295 - accuracy: 0.9885 - val_loss: 0.1878 - val_accuracy: 0.9500
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 6.103515470812226e-09.
# Epoch 11/20
# 40/40 [==============================] - 10s 245ms/step - loss: 0.0288 - accuracy: 0.9890 - val_loss: 0.2055 - val_accuracy: 0.9461
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 6.103515470812226e-09.
# Epoch 12/20
# 40/40 [==============================] - 10s 244ms/step - loss: 0.0299 - accuracy: 0.9883 - val_loss: 0.1963 - val_accuracy: 0.9479
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 3.051757735406113e-09.
# Epoch 13/20
# 40/40 [==============================] - 10s 244ms/step - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.2046 - val_accuracy: 0.9461
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 3.051757735406113e-09.
# Epoch 14/20
# 40/40 [==============================] - 10s 243ms/step - loss: 0.0282 - accuracy: 0.9890 - val_loss: 0.1996 - val_accuracy: 0.9473
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 3.051757735406113e-09.
# Epoch 15/20
# 40/40 [==============================] - 10s 246ms/step - loss: 0.0287 - accuracy: 0.9890 - val_loss: 0.1860 - val_accuracy: 0.9487
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 3.051757735406113e-09.
# Epoch 16/20
# 40/40 [==============================] - 10s 243ms/step - loss: 0.0285 - accuracy: 0.9890 - val_loss: 0.1915 - val_accuracy: 0.9487
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 1.5258788677030566e-09.
# Epoch 17/20
# 40/40 [==============================] - 10s 244ms/step - loss: 0.0291 - accuracy: 0.9886 - val_loss: 0.1858 - val_accuracy: 0.9482
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 1.5258788677030566e-09.
# Epoch 18/20
# 40/40 [==============================] - 10s 242ms/step - loss: 0.0287 - accuracy: 0.9890 - val_loss: 0.2001 - val_accuracy: 0.9468
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 1.5258788677030566e-09.
# Epoch 19/20
# 40/40 [==============================] - 10s 242ms/step - loss: 0.0301 - accuracy: 0.9883 - val_loss: 0.2029 - val_accuracy: 0.9468
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 1.5258788677030566e-09.
# Epoch 20/20
# 40/40 [==============================] - 10s 243ms/step - loss: 0.0298 - accuracy: 0.9884 - val_loss: 0.1887 - val_accuracy: 0.9491

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

# %%
initial_epochs = history.epoch[-1]
second_tune = 35-1
third_tune = 55-1
fourth_tune = 75-1

plt.figure(figsize=(12, 12))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
# plt.ylim([0.7, 1])
plt.plot([initial_epochs,initial_epochs], plt.ylim(), label='Start Fine Tuning')
plt.plot([second_tune,second_tune], plt.ylim(), label='Second Tuning')
# plt.plot([third_tune,third_tune], plt.ylim(), label='Third Tuning')
plt.plot([fourth_tune,fourth_tune], plt.ylim(), label='Fourth Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
# plt.ylim([0, 0.8])
plt.plot([initial_epochs,initial_epochs], plt.ylim(), label='Start Fine Tuning')
plt.plot([second_tune,second_tune], plt.ylim(), label='Second Tuning')
# plt.plot([third_tune,third_tune], plt.ylim(), label='Third Tuning')
plt.plot([fourth_tune,fourth_tune], plt.ylim(), label='Fourth Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
for lyr in model.layers[-88:]:
    lyr.trainable=True

# %%
for lyr in model.layers:
    lyr.trainable=True

# %%
model.save("/content/drive/My Drive/new_model_0_75_140")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/new_model_0_75_140/assets

# %%
import os
import random

# %%
TDIR = "garbage_dataset/test/"
samples = random.sample(os.listdir(TDIR),20)
for fp in samples:
    img = cv2.imread(TDIR+fp)
    img = cv2.resize(img, (IMG_HEIGHT, IMG_WIDTH))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB).astype(np.float32)
    img = img/255
    pred = model.predict(np.expand_dims(img,0)).squeeze()
    mask = cv2.resize(pred, img.shape[1::-1])
    plt.imshow(img)
    # plt.show()
    plt.imshow(mask, alpha=0.4)
    plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 158 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fdab7464bf8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
